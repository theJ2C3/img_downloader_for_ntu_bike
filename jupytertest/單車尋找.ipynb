# %%
##單日測試
from bs4 import BeautifulSoup
import requests
import os
from itertools import chain # the second of three
import datetime
import base64

##selecting date

now = datetime.date(2021, 4, 19)
delta = datetime.timedelta(days=-1)
date = (now + delta*11)
# print(date.strftime('%Y/%m/%d'))
A = str(date.strftime('%Y/%m/%d'))
Z = str(date.strftime('%Y-%m-%d'))
# print(Z)
##endding selecting date

##forming url
message_bytes = A.encode('ascii')
base64_bytes = base64.b64encode(message_bytes)
base64_message = base64_bytes.decode('ascii')
selected_date = base64_message
# print(base64_message)

##find link and number of picture
response = requests.get(f"https://mybike.ntu.edu.tw/bike.announcement/towing/fdate/{selected_date}/ftype/999")#daterelated
soup = BeautifulSoup(response.text, "lxml")
# print(response.text)

results = soup.find_all("img", limit=20)
image_links = [result.get("src") for result in results] 
results = soup.find_all("span", limit=62)
span_links = [span.text for span in results] 

del image_links[0]
del image_links[0]
del span_links[0]
del span_links[0]
span_links  = list(chain(*zip(span_links[1::3])))
span_links = span_links[:-1]
span_links = span_links[:-1]

string = 'https://mybike.ntu.edu.tw/'
image_links = [string + link for link in image_links]
##endding find link and number of picture

# print(image_links)
# print(span_links)

##download all pics
for index, link in enumerate(image_links, start=0):
 
    if not os.path.exists(Z):
        os.mkdir(Z)  
 
    img = requests.get(link)  
 
    with open(Z + "\\" + Z + "-" + span_links[index] + ".jpg", "wb") as file:  # 開啟資料夾及命名圖片檔#daterelated
        file.write(img.content)  # 寫入圖片的二進位碼
print("finish")
# Out:
# 2021/04/08
# finish

# %%
#多日分資料夾
from bs4 import BeautifulSoup
import requests
import os
from itertools import chain # the second of three
import datetime
import base64

def download_pic(date):
    A = str(date.strftime('%Y/%m/%d'))
    Z = str(date.strftime('%Y-%m-%d'))

    ##forming url
    message_bytes = A.encode('ascii')
    base64_bytes = base64.b64encode(message_bytes)
    base64_message = base64_bytes.decode('ascii')
    selected_date = base64_message
    # print(base64_message)

    ##find link and number of picture
    response = requests.get(f"https://mybike.ntu.edu.tw/bike.announcement/towing/fdate/{selected_date}/ftype/999")#daterelated
    soup = BeautifulSoup(response.text, "lxml")

    results = soup.find_all("img", limit=20)
    image_links = [result.get("src") for result in results]  # 取得圖片來源連結
    results = soup.find_all("span", limit=62)
    span_links = [span.text for span in results]  # 取得文字檔

    del image_links[0]
    del image_links[0]
    del span_links[0]
    del span_links[0]
    span_links  = list(chain(*zip(span_links[1::3])))
    span_links = span_links[:-1]
    span_links = span_links[:-1]

    string = 'https://mybike.ntu.edu.tw/'
    image_links = [string + link for link in image_links]
    ##endding find link and number of picture

    ##download all pics
    for index, link in enumerate(image_links, start=0):

        if not os.path.exists(Z):
            os.mkdir(Z)  # 建立資料夾 #daterelated

        img = requests.get(link)  # 下載圖片

        with open(Z + "\\" + Z + "-" + span_links[index] + ".jpg", "wb") as file:  # 開啟資料夾及命名圖片檔#daterelated
            file.write(img.content)  # 寫入圖片的二進位碼
            
    return None

##selecting date

now = datetime.date.today()
delta = datetime.timedelta(days=-1)
# day = now

for i in range(100):
        day = (now + delta*i)
        download_pic(day)
        print(day)

        
print("finish")
# Out:
# 2021-09-02
# 2021-09-01
# 2021-08-31
# 2021-08-30
# 2021-08-29
# 2021-08-28
# 2021-08-27
# 2021-08-26
# 2021-08-25
# 2021-08-24
# 2021-08-23
# 2021-08-22
# 2021-08-21
# 2021-08-20
# 2021-08-19
# 2021-08-18
# 2021-08-17
# 2021-08-16
# 2021-08-15
# 2021-08-14
# 2021-08-13
# 2021-08-12
# 2021-08-11
# 2021-08-10
# 2021-08-09
# 2021-08-08
# 2021-08-07
# 2021-08-06
# 2021-08-05
# 2021-08-04
# 2021-08-03
# 2021-08-02
# 2021-08-01
# 2021-07-31
# 2021-07-30
# 2021-07-29
# 2021-07-28
# 2021-07-27
# 2021-07-26
# 2021-07-25
# 2021-07-24
# 2021-07-23
# 2021-07-22
# 2021-07-21
# 2021-07-20
# 2021-07-19
# 2021-07-18
# 2021-07-17
# 2021-07-16
# 2021-07-15
# 2021-07-14
# 2021-07-13
# 2021-07-12
# 2021-07-11
# 2021-07-10
# 2021-07-09
# 2021-07-08
# 2021-07-07
# 2021-07-06
# 2021-07-05
# 2021-07-04
# 2021-07-03
# 2021-07-02
# 2021-07-01
# 2021-06-30
# 2021-06-29
# 2021-06-28
# 2021-06-27
# 2021-06-26
# 2021-06-25
# 2021-06-24
# 2021-06-23
# 2021-06-22
# 2021-06-21
# 2021-06-20
# 2021-06-19
# 2021-06-18
# 2021-06-17
# 2021-06-16
# 2021-06-15
# 2021-06-14
# 2021-06-13
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# 2021-06-05
# 2021-06-04
# 2021-06-03
# 2021-06-02
# 2021-06-01
# 2021-05-31
# 2021-05-30
# 2021-05-29
# 2021-05-28
# 2021-05-27
# 2021-05-26
# finish

# %%
#多日同一資料夾
from bs4 import BeautifulSoup
import requests
import os
from itertools import chain # the second of three
import datetime
import base64

def download_pic(date):
    A = str(date.strftime('%Y/%m/%d'))
    Z = str(date.strftime('%Y-%m-%d'))

    ##forming url
    message_bytes = A.encode('ascii')
    base64_bytes = base64.b64encode(message_bytes)
    base64_message = base64_bytes.decode('ascii')
    selected_date = base64_message
    # print(base64_message)

    ##find link and number of picture
    response = requests.get(f"https://mybike.ntu.edu.tw/bike.announcement/towing/fdate/{selected_date}/ftype/999")#daterelated
    soup = BeautifulSoup(response.text, "lxml")

    results = soup.find_all("img", limit=20)
    image_links = [result.get("src") for result in results]  # 取得圖片來源連結
    results = soup.find_all("span", limit=62)
    span_links = [span.text for span in results]  # 取得文字檔

    del image_links[0]
    del image_links[0]
    del span_links[0]
    del span_links[0]
    span_links  = list(chain(*zip(span_links[1::3])))
    span_links = span_links[:-1]
    span_links = span_links[:-1]

    string = 'https://mybike.ntu.edu.tw/'
    image_links = [string + link for link in image_links]
    ##endding find link and number of picture

    ##download all pics
    for index, link in enumerate(image_links, start=0):

        if not os.path.exists("pic"):
            os.mkdir("pic")  # 建立資料夾 #daterelated

        img = requests.get(link)  # 下載圖片

        with open("pic\\" + Z + "-" + span_links[index] + ".jpg", "wb") as file:  # 開啟資料夾及命名圖片檔#daterelated
            file.write(img.content)  # 寫入圖片的二進位碼
            
    return None

##selecting date

now = datetime.date.today()
delta = datetime.timedelta(days=-1)
# day = now

for i in range(100):
        day = (now + delta*i)
        download_pic(day)
        print(day)

        
print("finish")
# Out:
# 2021-09-02
# 2021-09-01
# 2021-08-31
# 2021-08-30
# 2021-08-29
# 2021-08-28
# 2021-08-27
# 2021-08-26
# 2021-08-25
# 2021-08-24
# 2021-08-23
# 2021-08-22
# 2021-08-21
# 2021-08-20
# 2021-08-19
# 2021-08-18
# 2021-08-17
# 2021-08-16
# 2021-08-15
# 2021-08-14
# 2021-08-13
# 2021-08-12
# 2021-08-11
# 2021-08-10
# 2021-08-09
# 2021-08-08
# 2021-08-07
# 2021-08-06
# 2021-08-05
# 2021-08-04
# 2021-08-03
# 2021-08-02
# 2021-08-01
# 2021-07-31
# 2021-07-30
# 2021-07-29
# 2021-07-28
# 2021-07-27
# 2021-07-26
# 2021-07-25
# 2021-07-24
# 2021-07-23
# 2021-07-22
# 2021-07-21
# 2021-07-20
# 2021-07-19
# 2021-07-18
# 2021-07-17
# 2021-07-16
# 2021-07-15
# 2021-07-14
# 2021-07-13
# 2021-07-12
# 2021-07-11
# 2021-07-10
# 2021-07-09
# 2021-07-08
# 2021-07-07
# 2021-07-06
# 2021-07-05
# 2021-07-04
# 2021-07-03
# 2021-07-02
# 2021-07-01
# 2021-06-30
# 2021-06-29
# 2021-06-28
# 2021-06-27
# 2021-06-26
# 2021-06-25
# 2021-06-24
# 2021-06-23
# 2021-06-22
# 2021-06-21
# 2021-06-20
# 2021-06-19
# 2021-06-18
# 2021-06-17
# 2021-06-16
# 2021-06-15
# 2021-06-14
# 2021-06-13
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# 2021-06-05
# 2021-06-04
# 2021-06-03
# 2021-06-02
# 2021-06-01
# 2021-05-31
# 2021-05-30
# 2021-05-29
# 2021-05-28
# 2021-05-27
# 2021-05-26
# finish

# %%
#多日同一資料夾
from bs4 import BeautifulSoup
import requests
import os
from itertools import chain # the second of three
import datetime
import base64

def download_pic(date):
    A = str(date.strftime('%Y/%m/%d'))
    Z = str(date.strftime('%Y-%m-%d'))

    ##forming url
    message_bytes = A.encode('ascii')
    base64_bytes = base64.b64encode(message_bytes)
    base64_message = base64_bytes.decode('ascii')
    selected_date = base64_message
    # print(base64_message)

    ##find link and number of picture
    response = requests.get(f"https://mybike.ntu.edu.tw/bike.announcement/towing/fdate/{selected_date}/ftype/999")#daterelated
    soup = BeautifulSoup(response.text, "lxml")

    results = soup.find_all("img", limit=20)
    image_links = [result.get("src") for result in results]  # 取得圖片來源連結
    results = soup.find_all("span", limit=62)
    span_links = [span.text for span in results]  # 取得文字檔

    del image_links[0]
    del image_links[0]
    del span_links[0]
    del span_links[0]
    span_links  = list(chain(*zip(span_links[1::3])))
    span_links = span_links[:-1]
    span_links = span_links[:-1]

    string = 'https://mybike.ntu.edu.tw/'
    image_links = [string + link for link in image_links]
    ##endding find link and number of picture

    ##download all pics
    for index, link in enumerate(image_links, start=0):

        if not os.path.exists("pic"):
            os.mkdir("pic")  # 建立資料夾 #daterelated

        img = requests.get(link)  # 下載圖片

        with open("pic\\" + Z + "-" + span_links[index] + ".jpg", "wb") as file:  # 開啟資料夾及命名圖片檔#daterelated
            file.write(img.content)  # 寫入圖片的二進位碼
            
    return None

##selecting date

now = datetime.date.today()
delta = datetime.timedelta(days=-1)
# day = now

for i in range(100):
        day = (now + delta*i)
        download_pic(day)
        print(day)

        
print("finish")
# Out:
# 2021-09-02
# 2021-09-01
# 2021-08-31
# 2021-08-30
# 2021-08-29
# 2021-08-28
# 2021-08-27
# 2021-08-26
# 2021-08-25
# 2021-08-24
# 2021-08-23
# 2021-08-22
# 2021-08-21
# 2021-08-20
# 2021-08-19
# 2021-08-18
# 2021-08-17
# 2021-08-16
# 2021-08-15
# 2021-08-14
# 2021-08-13
# 2021-08-12
# 2021-08-11
# 2021-08-10
# 2021-08-09
# 2021-08-08
# 2021-08-07
# 2021-08-06
# 2021-08-05
# 2021-08-04
# 2021-08-03
# 2021-08-02
# 2021-08-01
# 2021-07-31
# 2021-07-30
# 2021-07-29
# 2021-07-28
# 2021-07-27
# 2021-07-26
# 2021-07-25
# 2021-07-24
# 2021-07-23
# 2021-07-22
# 2021-07-21
# 2021-07-20
# 2021-07-19
# 2021-07-18
# 2021-07-17
# 2021-07-16
# 2021-07-15
# 2021-07-14
# 2021-07-13
# 2021-07-12
# 2021-07-11
# 2021-07-10
# 2021-07-09
# 2021-07-08
# 2021-07-07
# 2021-07-06
# 2021-07-05
# 2021-07-04
# 2021-07-03
# 2021-07-02
# 2021-07-01
# 2021-06-30
# 2021-06-29
# 2021-06-28
# 2021-06-27
# 2021-06-26
# 2021-06-25
# 2021-06-24
# 2021-06-23
# 2021-06-22
# 2021-06-21
# 2021-06-20
# 2021-06-19
# 2021-06-18
# 2021-06-17
# 2021-06-16
# 2021-06-15
# 2021-06-14
# 2021-06-13
# 2021-06-12
# 2021-06-11
# 2021-06-10
# 2021-06-09
# 2021-06-08
# 2021-06-07
# 2021-06-06
# 2021-06-05
# 2021-06-04
# 2021-06-03
# 2021-06-02
# 2021-06-01
# 2021-05-31
# 2021-05-30
# 2021-05-29
# 2021-05-28
# 2021-05-27
# 2021-05-26
# finish
